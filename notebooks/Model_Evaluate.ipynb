# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
category_log = {'category_accuracy': [0.5409145355224609, 0.7574170231819153, 0.8125391602516174, 0.8325266242027283, 0.8532543778419495, 0.8628779649734497, 0.8707932233810425, 0.8840043544769287, 0.8912932276725769, 0.8975570797920227, 0.9040487408638, 0.9090598225593567, 0.9170320630073547, 0.9194806814193726, 0.9224987030029297, 0.924605667591095, 0.9279084205627441, 0.9307556748390198, 0.9321222901344299, 0.932691752910614, 0.9372473359107971, 0.9371334314346313, 0.9398667216300964, 0.9420306086540222, 0.9450486898422241, 0.9469278454780579, 0.9448208808898926, 0.9451625943183899, 0.9479528665542603, 0.9482945203781128], 'grade_accuracy': [0.24041910469532013, 0.24440521001815796, 0.24133022129535675, 0.24548715353012085, 0.2416149377822876, 0.24241216480731964, 0.2426399439573288, 0.24383577704429626, 0.24320939183235168, 0.24298161268234253, 0.24406355619430542, 0.24446216225624084, 0.2425829917192459, 0.2462843805551529, 0.24138715863227844, 0.24708160758018494, 0.24189966917037964, 0.2426399439573288, 0.24736632406711578, 0.2430955022573471, 0.24030521512031555, 0.24451909959316254, 0.24383577704429626, 0.24252605438232422, 0.2452593743801117, 0.24918854236602783, 0.2441204935312271, 0.24224132299423218, 0.24036216735839844, 0.24554410576820374]}
category = pd.DataFrame.from_dict(category_log)
category.reset_index()
category
# Out:
#     category_accuracy  grade_accuracy
# 0            0.540915        0.240419
# 1            0.757417        0.244405
# 2            0.812539        0.241330
# 3            0.832527        0.245487
# 4            0.853254        0.241615
# 5            0.862878        0.242412
# 6            0.870793        0.242640
# 7            0.884004        0.243836
# 8            0.891293        0.243209
# 9            0.897557        0.242982
# 10           0.904049        0.244064
# 11           0.909060        0.244462
# 12           0.917032        0.242583
# 13           0.919481        0.246284
# 14           0.922499        0.241387
# 15           0.924606        0.247082
# 16           0.927908        0.241900
# 17           0.930756        0.242640
# 18           0.932122        0.247366
# 19           0.932692        0.243096
# 20           0.937247        0.240305
# 21           0.937133        0.244519
# 22           0.939867        0.243836
# 23           0.942031        0.242526
# ...

# %%
plt.figure(figsize=(12,6))
plt.plot(category.index, category['category_accuracy'], label = 'Category Accuracy', marker = 'o')
plt.plot(category.index, category['grade_accuracy'], label = 'Grade Accuracy', marker = 'o')

plt.xlabel('Epoch', fontsize = 20)
plt.ylabel('Accuracy', fontsize = 20)
plt.title('Lambda = 0', fontdict={'fontsize': 20, 'fontweight': 'bold', 'family': 'serif'})
plt.yticks(np.arange(0.2, 1, 0.1))
plt.legend(fontsize = 20, loc=(0.6,0.25))
plt.grid(True)
plt.tick_params(axis='both', which='major', labelsize=18)
plt.savefig('Multitask_Learning_Lambda_0.png')
plt.show()

# %%
grade_log = {'category_accuracy': [0.26467740535736084, 0.27042877674102783, 0.26917600631713867, 0.27452877163887024, 0.2777176797389984, 0.2787996232509613, 0.28016626834869385, 0.2864871025085449, 0.28261488676071167, 0.28893572092056274, 0.2834120988845825, 0.2907579243183136, 0.29406070709228516, 0.29047319293022156, 0.2939468026161194, 0.29679402709007263, 0.2959968149662018, 0.29463014006614685, 0.2959968149662018, 0.29457318782806396, 0.294857919216156, 0.2970218062400818, 0.29519960284233093, 0.29622459411621094, 0.2948009669780731, 0.29457318782806396, 0.29730653762817383, 0.297534316778183, 0.2983884811401367, 0.29764819145202637], 'grade_accuracy': [0.6549171209335327, 0.7966516613960266, 0.8416377305984497, 0.8757473826408386, 0.8920334577560425, 0.9073514938354492, 0.9173167943954468, 0.9279654026031494, 0.9367347955703735, 0.946415364742279, 0.9474403262138367, 0.9548431038856506, 0.9571778178215027, 0.9648084044456482, 0.9680542349815369, 0.9686806201934814, 0.9720402956008911, 0.9744889140129089, 0.9757416844367981, 0.9771652817726135, 0.979044497013092, 0.9793291687965393, 0.9814930558204651, 0.9818916916847229, 0.9834291934967041, 0.9844542145729065, 0.9847388863563538, 0.9858778119087219, 0.9858778119087219, 0.9871875047683716]}
grade = pd.DataFrame.from_dict(grade_log)
grade.reset_index()
grade
# Out:
#     category_accuracy  grade_accuracy
# 0            0.264677        0.654917
# 1            0.270429        0.796652
# 2            0.269176        0.841638
# 3            0.274529        0.875747
# 4            0.277718        0.892033
# 5            0.278800        0.907351
# 6            0.280166        0.917317
# 7            0.286487        0.927965
# 8            0.282615        0.936735
# 9            0.288936        0.946415
# 10           0.283412        0.947440
# 11           0.290758        0.954843
# 12           0.294061        0.957178
# 13           0.290473        0.964808
# 14           0.293947        0.968054
# 15           0.296794        0.968681
# 16           0.295997        0.972040
# 17           0.294630        0.974489
# 18           0.295997        0.975742
# 19           0.294573        0.977165
# 20           0.294858        0.979044
# 21           0.297022        0.979329
# 22           0.295200        0.981493
# 23           0.296225        0.981892
# ...

# %%
plt.figure(figsize=(12,6))
plt.plot(grade.index, grade['category_accuracy'], label = 'Category Accuracy', marker = 'o')
plt.plot(grade.index, grade['grade_accuracy'], label = 'Grade Accuracy', marker = 'o')

plt.xlabel('Epoch', fontsize = 20)
plt.ylabel('Accuracy', fontsize = 20)
plt.title('Lambda = 1', fontdict={'fontsize': 20, 'fontweight': 'bold', 'family': 'serif'})
plt.yticks(np.arange(0.2, 1, 0.1))
plt.legend(fontsize = 20, loc=(0.6,0.25))
plt.grid(True)
plt.tick_params(axis='both', which='major', labelsize=18)
plt.savefig('Multitask_Learning_Lambda_1.png')
plt.show()

# %%
relation_log = {'category_accuracy': [0.314048171043396, 0.3942827880382538, 0.47713685035705566, 0.5381242632865906, 0.5808894634246826, 0.6241672039031982, 0.6598143577575684, 0.6853254437446594, 0.705426812171936, 0.7292864918708801], 'grade_accuracy': [0.5811172723770142, 0.7313934564590454, 0.7823586463928223, 0.8098058104515076, 0.8369683027267456, 0.8525710105895996, 0.8627640604972839, 0.8774557113647461, 0.8839473724365234, 0.8937987685203552]}
relation = pd.DataFrame.from_dict(relation_log)
relation.reset_index()
relation
# Out:
#    category_accuracy  grade_accuracy
# 0           0.314048        0.581117
# 1           0.394283        0.731393
# 2           0.477137        0.782359
# 3           0.538124        0.809806
# 4           0.580889        0.836968
# 5           0.624167        0.852571
# 6           0.659814        0.862764
# 7           0.685325        0.877456
# 8           0.705427        0.883947
# 9           0.729286        0.893799

# %%
plt.figure(figsize=(12,6))
plt.plot(relation.index, relation['category_accuracy'], label = 'Category Accuracy', marker = 'o')
plt.plot(relation.index, relation['grade_accuracy'], label = 'Grade Accuracy', marker = 'o')

plt.xlabel('Epoch', fontsize = 20)
plt.ylabel('Accuracy', fontsize = 20)
plt.title('Lambda = 0, Sigma = 0.05', fontdict={'fontsize': 20, 'fontweight': 'bold', 'family': 'serif'})
plt.yticks(np.arange(0.25, 0.95, 0.1))
plt.legend(fontsize = 20, loc=(0.6,0.25))
plt.grid(True)
plt.tick_params(axis='both', which='major', labelsize=18)
plt.savefig('Multitask_Learning_Create_Connection.png')
plt.show()

# %%
effect_log = {'category_accuracy': [0.7574170231819153, 0.7952280640602112, 0.8181197047233582, 0.8357724547386169, 0.8479585647583008, 0.859347403049469, 0.8709640502929688, 0.878537654876709, 0.8815557360649109, 0.895962655544281], 'grade_accuracy': [0.9018848538398743, 0.9016001224517822, 0.9031376242637634, 0.9072376489639282, 0.9076932072639465, 0.909401535987854, 0.9112806916236877, 0.9123626351356506, 0.9126473665237427, 0.9161209464073181]}
effect = pd.DataFrame.from_dict(effect_log)
effect.reset_index()
effect
# Out:
#    category_accuracy  grade_accuracy
# 0           0.757417        0.901885
# 1           0.795228        0.901600
# 2           0.818120        0.903138
# 3           0.835772        0.907238
# 4           0.847959        0.907693
# 5           0.859347        0.909402
# 6           0.870964        0.911281
# 7           0.878538        0.912363
# 8           0.881556        0.912647
# 9           0.895963        0.916121

# %%
plt.figure(figsize=(12,6))
plt.plot(effect.index, effect['category_accuracy'], label = 'Category Accuracy', marker = 'o')
plt.plot(effect.index, effect['grade_accuracy'], label = 'Grade Accuracy', marker = 'o')

plt.xlabel('Epoch', fontsize = 20)
plt.ylabel('Accuracy', fontsize = 20)
plt.title('Lambda = 0, Sigma = 0', fontdict={'fontsize': 20, 'fontweight': 'bold', 'family': 'serif'})
plt.yticks(np.arange(0.75, 0.95, 0.025))
plt.legend(fontsize = 20, loc=(0.6,0.25))
plt.grid(True)

plt.tick_params(axis='both', which='major', labelsize=20)
plt.savefig('Multitask_Learning_Hierarchical_test.png')
plt.show()
